# %%
import tweepy as tw
import pandas as pd
import numpy as np

# %%
consumer_key= 'XXXXXXXXXXXXXXXXXXXX'
consumer_secret= 'XXXXXXXXXXXXXXXXXXXX'
access_token= 'XXXXXXXXXXXXXXXXXXXX'
access_token_secret= 'XXXXXXXXXXXXXXXXXXXX'

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
search_words = "@coronavirus"
date_since = "2020-03-29"

# %%
tweets = tw.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since).items(100)

# %%
tweet_details = [[tweet.geo, tweet.text,tweet.user.screen_name, tweet.user.location] for tweet in tweets]

# %%
tweet_details
# Out:
# [[None, '@coronavirus stop', 'David_Ordure', ''],
#  [None,
#   'RT @moderateRepand1: @filnj @YouTube 2/24/2020\n@SpeakerPelosi asks people to "come to #Chinatown"\n\nRolls into #DC &amp; holds up @coronavirus #…',
#   'TJentilucci',
#   'USA'],
#  [None,
#   'RT @moderateRepand1: Please #GetWellSoon\n@ChrisCuomo\n@coronavirus has no boundaries &amp; at this time in history #IDEOLOGY, #Race, #Political…',
#   'moderateRepand1',
#   'New Jersey, USA'],
#  [None,
#   'Please #GetWellSoon\n@ChrisCuomo\n@coronavirus has no boundaries &amp; at this time in history #IDEOLOGY, #Race,… https://t.co/UU3KfzolqX',
#   'moderateRepand1',
#   'New Jersey, USA'],
#  [None,
#   'RT @moderateRepand1: @filnj @YouTube 2/24/2020\n@SpeakerPelosi asks people to "come to #Chinatown"\n\nRolls into #DC &amp; holds up @coronavirus #…',
#   'moderateRepand1',
#   'New Jersey, USA'],
#  [None,
#   '@filnj @YouTube 2/24/2020\n@SpeakerPelosi asks people to "come to #Chinatown"\n\nRolls into #DC &amp; holds up… https://t.co/Dmi0FnSR8w',
#   'moderateRepand1',
#   'New Jersey, USA'],
#  [None,
#   'CatholicMom: Plagues, Wars, Facebook and Hope What new experiences is God using you to draw you closer to him this… https://t.co/M5u694wFVC',
#   'NancyHCWard',
#   'Dallas'],
#  [None,
#   'America’s healthcare workers are at war, if they were the army, they would not be told to get their own guns and bu… https://t.co/vuslwF9wqY',
#   'FlyEagles4',
#   'New Jersey, USA'],
#  [None,
#   'RT @moderateRepand1: @DRoho57 @musings_mary Or wants to spread the @coronavirus to Millions',
#   'moderateRepand1',
#   'New Jersey, USA'],
#  [None,
#   '@DRoho57 @musings_mary Or wants to spread the @coronavirus to Millions',
#   'moderateRepand1',
#   'New Jersey, USA'],
#  [None,
#   "Hey @coronavirus if you infect my boy @howiemandel, im comin' for you",
#   'Boone_Tang',
#   'England, United Kingdom'],
#  [None,
#   '@coronavirus stop it. It would be very kind of you.',
#   'JimmyMcGuinnes7',
#   ''],
#  [None,
#   '@afiasalam @zubairabbasi @coronavirus @indushospitalpk @sepa @MoCCPak @murtazawahab1 @aminattock @fawadchaudhry… https://t.co/f4rxygcboI',
#   'AmnaadnanAD',
#   ''],
#  [None,
#   'Plant lovers please help !  Retweet to make awareness \nPlants will die - \nGovernment please do something ..… https://t.co/nye5gZMnNZ',
#   'CatherineCoombs',
#   ''],
#  [None,
#   'RT @back_fights: @ResistUK1 @BorisJohnson @coronavirus Spread the word - \nThe @GoodLawProject\n is offering to provide legal advice and whis…',
#   'dafyddmihangel',
#   'Cymru (Wales to all Heathens)'],
#  [None,
#   "RT @benjamat10: @futurelawdigita @bernerlap @BBCNews @coronavirus It's the British formula 1 team.\n\nAlmost all from Britain.\n\nMercedes is j…",
#   'benjamat10',
#   'Wales, United Kingdom'],
#  [None, '@coronavirus yall messin up my diet bro', 'BigBallerHassan', ''],
#  [None,
#   'Having rosół with udon noodles tomorrow due to limited stocks at the supermarket. Thanks a lot @Coronavirus, you ar… https://t.co/2xADi3KaKC',
#   'wifeyriddim',
#   'North west LONDOn'],
#  [None, '@coronavirus please say april fools', 'joshuacej', ''],
#  [None,
#   'RT @nkosi_milton: Spare a few minutes to watch the Roedean Choir perform a moving rendition of Hallelujah, conducted by the one and only @r…',
#   'joshglancy',
#   'Washington, DC'],
#  [None,
#   'RT @JonDelano: Working from home, @PAAttorneyGen @JoshShapiroPA tells me he is working with banks and lending institutions to get a 90-day…',
#   'ebner_jane',
#   ''],
#  [None,
#   '@ImFrank85116396 @daily_trust @hunger @coronavirus Really bad make God almighty help us Corona virus doing his own… https://t.co/f0TLqhHZbR',
#   'Adewumioluwad14',
#   'Obanikoro, Lagos '],
#  [None,
#   '@SimJoeMoore @CatherineSoph13 @coronavirus @mitchellvii @ScottAdamsSays Waiting patiently .. https://t.co/LgAnEwDO1g',
#   'Skuby1968',
#   'Dublin'],
#  [None,
#   '@OMGno2trump Takes in millions, pays no taxes, turns those in need away from his church. #Osteen just another cult… https://t.co/IwBO4UZLtZ',
#   'donholt99',
#   'Texas, USA'],
#  [None,
#   "China's notorious 'wet markets' have reopened - selling bats, pangolins and dogs for human consu... -… https://t.co/4tveFdFQ7o",
#   'NarenTada',
#   'india'],
#  [None,
#   '@JonDelano @KDKA @PAAttorneyGen @JoshShapiroPA @coronavirus @PNCBank Wow wonder if he will run for governor',
#   'fredmoser4',
#   ''],
#  [None,
#   'RT @ResistUK1: Why can’t @BorisJohnson be like this man. A leader, strategist and a fighter of @coronavirus https://t.co/R8XAiSTEAm',
#   'AndyRFCCharman',
#   'London, UK, EUROPE'],
#  [None,
#   '@Gword17 @ryukenonvavoir @coronavirus rawoe',
#   'JeanYvesMouette',
#   'Trinity Church, enterré avec mon pote Jesus'],
#  [None,
#   'Sunset in the time of coronavirus\nPhoto@manisha jain\n@coronavirus\n@sunset\n@photograph\n@photooftheday https://t.co/WymfqJFlgB',
#   'manisha165a',
#   ''],
#  [None,
#   "RT @akerele_s: Why can't they seat at home and worship I now realized why Bill Gates said Millions of Africa will die of coronavirus. Fake…",
#   'mashegoTC07',
#   'Pretoria and NYC'],
#  [None, '@coronavirus fuck You', 'JohnJoyal', ''],
#  [None,
#   '@Gword17 @ryukenonvavoir @coronavirus pas top 40 sel',
#   'JeanYvesMouette',
#   'Trinity Church, enterré avec mon pote Jesus'],
#  [None,
#   '@None_Otha30 @coronavirus I am chill. It’s the Rona that’s tripping 🤣🤣',
#   'itsdavidaj',
#   ''],
#  [None,
#   'RT @Sukithompson: How entrepreneurs can rise like a Phoenix as @coronavirus impacts https://t.co/yHorvmv4cw   @letsreset1  @Siftedeu @Debbi…',
#   'weare3sixty',
#   'London, England'],
#  [None,
#   'RT @globelamp: Please listen to my friend @feelingXbae who lives in Italy about the severity of the @coronavirus and why you need to self i…',
#   'dianasample14',
#   ''],
#  [None,
#   '@itsdavidaj @coronavirus Aye I’m gonna need you to find some chill 🤣🤣',
#   'None_Otha30',
#   'my header where it all started'],
#  [None,
#   '@coronavirus can you let us back on the field please ? https://t.co/yLFeG8urgI',
#   'mo3_lyfstyle',
#   ''],
#  [None,
#   "@coronavirus I'm currently on the last season of How I met your Mother so you better be ending soon.",
#   'tanggal2lima',
#   'Indonesia'],
#  [None,
#   'Now I have a reason to be scared of old people @coronavirus',
#   'HaydenAlexis3',
#   ''],
#  [None,
#   "@futurelawdigita @bernerlap @BBCNews @coronavirus It's the British formula 1 team.\n\nAlmost all from Britain.\n\nMerce… https://t.co/vhxQTAd5pl",
#   'benjamat10',
#   'Wales, United Kingdom'],
#  [None, '@coronavirus stop', 'RossIsBoss247', ''],
#  [None,
#   '@Coronavirus bitch I done beat my meat 422 times in the last 2 days. HURRY UP &amp; LEAVE',
#   'itsdavidaj',
#   ''],
#  [None, 'I WANT MY LIFE BACK!!! @coronavirus', 'SooSUSPENDED', 'NYC'],
#  [None,
#   '@gnuman1979 6 ft is because it gives a big (not total) protection, is doable in society and flattens the curve on h… https://t.co/Ff9LaajRl0',
#   '1martschipper1',
#   ''],
#  [None,
#   'RT @back_fights: @ResistUK1 @BorisJohnson @coronavirus Spread the word - \nThe @GoodLawProject\n is offering to provide legal advice and whis…',
#   'Sparkletutu',
#   'Great Yarmouth, England'],
#  [None,
#   'RT @futurelawdigita: @BBCNews Remember in Apollo13 when necessity drove NASA engineers to create urgently a device to filter cabin air? Now…',
#   'KRIX60',
#   'On a blue moon'],
#  [None,
#   'RT @futurelawdigita: @BBCNews Remember in Apollo13 when necessity drove NASA engineers to create urgently a device to filter cabin air? Now…',
#   'bernerlap',
#   'up a hill'],
#  [None,
#   '@ScoonTv @Coronavirus come get this nigga, he’s wasting oxygen',
#   'fruitiiiz',
#   'Mars '],
#  [None,
#   'Daily wage labour can donate 251 rs from 392 rs  to pm care and promote his tweet atleast do something logical 🤷\u200d♂️… https://t.co/D9fvCmqKdn',
#   'shahid7750',
#   'Modasa'],
#  [None,
#   '"if you want to go out, and act stupid" you can do it so, but please don\'t come back home to infect the other peopl… https://t.co/VzYGeR43r6',
#   'vvibrown',
#   ''],
#  [None,
#   'This is going to be a beautiful day! #chriscuomo @coronavirus\nCNN Host Chris Cuomo Tests Positive for Coronavirus… https://t.co/O4uDkfVOPp',
#   'kryptocrib',
#   ''],
#  [None,
#   'CM sahab.. where are your measures? \nMany of people are effected.. where is ration distribution service team?… https://t.co/VNJqbih8Ep',
#   'ansari_98',
#   'Pakistan'],
#  [None,
#   '@JonDelano @KDKA @PAAttorneyGen @JoshShapiroPA @coronavirus @PNCBank How about suspending interest on mortgages tha… https://t.co/1GDv8W25hu',
#   'jaydotseedot',
#   ''],
#  [None,
#   'RT @back_fights: @ResistUK1 @BorisJohnson @coronavirus Spread the word - \nThe @GoodLawProject\n is offering to provide legal advice and whis…',
#   'ApertureImage',
#   'North of the Isle of Wight!'],
#  [None,
#   'HANG IT UPPPPPP @coronavirus',
#   'BUTERANISM',
#   'backup: @theroofbutera'],
#  [None, '@tylcox34 You are in trouble @coronavirus!', 'Jcausey21', ''],
#  [None,
#   'RT @back_fights: @ResistUK1 @BorisJohnson @coronavirus Spread the word - \nThe @GoodLawProject\n is offering to provide legal advice and whis…',
#   'AlanUrdaibay',
#   ''],
#  [None,
#   'RT @JonDelano: Working from home, @PAAttorneyGen @JoshShapiroPA tells me he is working with banks and lending institutions to get a 90-day…',
#   'DePasqualePA',
#   'York, PA'],
#  [None,
#   'Listen in as I go through Small Business Administration COVID 19 funding options https://t.co/P45csVTDVA #covid19… https://t.co/9gLOullrh0',
#   'shaneSnipes',
#   'New York, NY'],
#  [None,
#   'What?  @ChrisCuomo has @Coronavirus get well soon #cuomobrothers',
#   'Old_Hippi',
#   ''],
#  [None,
#   'RT @back_fights: @ResistUK1 @BorisJohnson @coronavirus Spread the word - \nThe @GoodLawProject\n is offering to provide legal advice and whis…',
#   'ResistUK1',
#   ''],
#  [None,
#   'RT @back_fights: @ResistUK1 @BorisJohnson @coronavirus Spread the word - \nThe @GoodLawProject\n is offering to provide legal advice and whis…',
#   'davebancroft',
#   ''],
#  [None,
#   'RT @JonDelano: Working from home, @PAAttorneyGen @JoshShapiroPA tells me he is working with banks and lending institutions to get a 90-day…',
#   'dshank92',
#   'Pittsburgh, PA'],
#  [None,
#   '@ResistUK1 @BorisJohnson @coronavirus Spread the word - \nThe @GoodLawProject\n is offering to provide legal advice a… https://t.co/ungD8PXgzo',
#   'back_fights',
#   ''],
#  [None,
#   '@JonDelano @PAAttorneyGen @JoshShapiroPA @coronavirus @PNCBank @KDKA Yes yes yes',
#   'lauralies10p',
#   'pennsylvania'],
#  [None,
#   'RT @JonDelano: Working from home, @PAAttorneyGen @JoshShapiroPA tells me he is working with banks and lending institutions to get a 90-day…',
#   'lauralies10p',
#   'pennsylvania'],
#  [None,
#   'Why can’t @BorisJohnson be like this man. A leader, strategist and a fighter of @coronavirus https://t.co/R8XAiSTEAm',
#   'ResistUK1',
#   ''],
#  [None,
#   '@haydenthill @coronavirus I’m only here to help',
#   'cynthiaaceleste',
#   ''],
#  [None,
#   'RT @haydenthill: @cynthiaaceleste @coronavirus Ladies and gentlemen. We found the cure.',
#   'cynthiaaceleste',
#   ''],
#  [None,
#   'consecutive hour three (3) of bar rescue pls go away @coronavirus',
#   'CJWalters07',
#   'New Jersey, USA'],
#  [None,
#   "@coronavirus has turned us all into dogs. We roam the house all day looking for food. We're told NO if we get too c… https://t.co/WdEHwjW0R3",
#   'isseyhorse1',
#   'Bolton, England United Kingdom'],
#  [None,
#   '@coronavirus @sol_nado @bluesabredavis @Xubuntu I want your @ so badly lol',
#   'ImBoredAriG',
#   '6.8.19 🖤 11.19.19 🖤'],
#  [None, 'F*CK YOU! @CoronaVirus', 'gentlyfading', ''],
#  [None,
#   "@CoronaVirus brought rich, Prime Minister clapped, but hungry, thirsty 'poor' is dying on the road.",
#   'upendra_bage',
#   'Bhubaneswar,Odisha'],
#  [None,
#   'Seeking advice for a friend who is a @coronavirus scientist, now doing TV and video interviews. She needs DIY advic… https://t.co/fJanDf8ZOk',
#   'QuantumDottie',
#   'NYC'],
#  [None,
#   '@JonDelano @PAAttorneyGen @JoshShapiroPA @coronavirus @PNCBank @KDKA Sorely needed. If income has been frozen big e… https://t.co/r0qgAzLEfL',
#   'benwren',
#   'iPhone: 40.425628,-79.908375'],
#  [None,
#   "RT @_nxgy2: hey @coronavirus fuck you man, i'll broke your ass gtfo here you fucked up virus come here e glub glub no meu ovo you filho da…",
#   'renatin_1',
#   ''],
#  [None, 'Stop @coronavirus', 'V2V_Moulaga', 'Toulouse, France'],
#  [None,
#   'RT @RakeshS54132165: Animal is better than human... against covid-19....he teaches the lesson to whole world tat physical distancing is bet…',
#   'africanking101',
#   ''],
#  [None,
#   '#cutmyownhairchallenge if u support social distancing u should participate !! Remember world I said it first!! @realDonaldTrump @coronavirus',
#   'KorrectG',
#   ''],
#  [None,
#   "hey @coronavirus fuck you man, i'll broke your ass gtfo here you fucked up virus come here e glub glub no meu ovo you filho da puta",
#   '_nxgy2',
#   'São Paulo, Brasil'],
#  [None,
#   '#SOS \npolice roit in @coronavirus\n\nPhoto: HSUSU\n#tiananmen1989 reissue\n#HKPoliceTerrorism\n#savehk\n#FreeHongKong… https://t.co/ixL0Kc4fUG',
#   'SoSaveHK',
#   ''],
#  [None,
#   'RT @jdnyc75: @gofundme @GoFundMeCharity @COVID19Tracking @covidperspectiv @NYCDadsGroup\n@NYCDCA @EssentialEmploy @dads #COVID19 #coronaviru…',
#   'Jennife99007521',
#   'Maple, Wisconsin '],
#  [None,
#   '@cynthiaaceleste @coronavirus Ladies and gentlemen. We found the cure.',
#   'haydenthill',
#   'Temecula, CA'],
#  [None,
#   "Today Finally got a positive case's of @coronavirus in @assam, Allah Save us from @CORONAVIRUS😰😰 @PMOIndia @sarbanandsonwal @_DigitalIndia",
#   'Zohi98104Islam',
#   'Barpeta Road, India'],
#  [None,
#   'RT @futurelawdigita: @BBCNews Remember in Apollo13 when necessity drove NASA engineers to create urgently a device to filter cabin air? Now…',
#   'futurelawdigita',
#   'Wheathampstead, England'],
#  [None,
#   'RT @JonDelano: Working from home, @PAAttorneyGen @JoshShapiroPA tells me he is working with banks and lending institutions to get a 90-day…',
#   'jayhan181',
#   'lil boston pa.'],
#  [None,
#   "@goairlinesindia don't be so deaf to the current situation cz of @coronavirus Why aren't you giving the option of c… https://t.co/fKITFK3G65",
#   'kvp1982',
#   ''],
#  [None,
#   'RT @DSchaubacher: #Gender #Equality : article by European Institute for Gender Equality : how the @coronavirus @pandemic puts women in the…',
#   'nembotavy_0101',
#   ''],
#  [None,
#   'RT @futurelawdigita: @BBCNews Remember in Apollo13 when necessity drove NASA engineers to create urgently a device to filter cabin air? Now…',
#   'Wessexlaw1',
#   ''],
#  [None,
#   'RT @futurelawdigita: @BBCNews Remember in Apollo13 when necessity drove NASA engineers to create urgently a device to filter cabin air? Now…',
#   'labrumsfuture',
#   ''],
#  [None,
#   'RT @JonDelano: Working from home, @PAAttorneyGen @JoshShapiroPA tells me he is working with banks and lending institutions to get a 90-day…',
#   'joeradosevich',
#   'The North'],
#  [None,
#   'RT @futurelawdigita: @BBCNews Remember in Apollo13 when necessity drove NASA engineers to create urgently a device to filter cabin air? Now…',
#   'lawgenisis',
#   ''],
#  [None,
#   '#Gender #Equality : article by European Institute for Gender Equality : how the @coronavirus @pandemic puts women i… https://t.co/DtwI5oVB70',
#   'DSchaubacher',
#   'Bruxelles'],
#  [None,
#   'RT @JonDelano: Working from home, @PAAttorneyGen @JoshShapiroPA tells me he is working with banks and lending institutions to get a 90-day…',
#   'JoAnnKennedyCAN',
#   ''],
#  [None,
#   'RT @JonDelano: Working from home, @PAAttorneyGen @JoshShapiroPA tells me he is working with banks and lending institutions to get a 90-day…',
#   'quincy4council',
#   'Pittsburgh PA'],
#  [None,
#   'Now we are officially at war with @coronavirus . It’s not just cruise ships anymore. Will @realDonaldTrump let the… https://t.co/kEMXvdWLup',
#   'FRInglis',
#   ''],
#  [None,
#   'Bollywood Star requesting people to stay at Home | Noida News India | Ak... https://t.co/UcL4A7MjON via @YouTube… https://t.co/FL40nheUGl',
#   'NoidaNewsIndia',
#   'New Delhi, India'],
#  [None,
#   'RT @jdnyc75: @gofundme @GoFundMeCharity @COVID19Tracking @covidperspectiv @NYCDadsGroup\n@NYCDCA @EssentialEmploy @dads #COVID19 #coronaviru…',
#   'jdnyc75',
#   ''],
#  [None,
#   'The Maulana must be arrested ed and tried for homicide. His speeches making fun of the @coronavirus scare and lockd… https://t.co/xXJIbSukFt',
#   'girishnjha',
#   'JNU New Delhi']]

# %%
import pandas as pd
tweet_df=pd.DataFrame(data=tweet_details,columns=["geo","text","user","location"])
pd.set_option('max_colwidth',800)
tweet_df.head(10)
# Out:
#     geo  \
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None
# 5  None
# 6  None
# 7  None
# 8  None
# 9  None
#
#                                                                                                                                                   text  \
# 0                                                                                                                                    @coronavirus stop
# 1  RT @moderateRepand1: @filnj @YouTube 2/24/2020\n@SpeakerPelosi asks people to "come to #Chinatown"\n\nRolls into #DC &amp; holds up @coronavirus #…
# 2    RT @moderateRepand1: Please #GetWellSoon\n@ChrisCuomo\n@coronavirus has no boundaries &amp; at this time in history #IDEOLOGY, #Race, #Political…
# 3            Please #GetWellSoon\n@ChrisCuomo\n@coronavirus has no boundaries &amp; at this time in history #IDEOLOGY, #Race,… https://t.co/UU3KfzolqX
# 4  RT @moderateRepand1: @filnj @YouTube 2/24/2020\n@SpeakerPelosi asks people to "come to #Chinatown"\n\nRolls into #DC &amp; holds up @coronavirus #…
# 5              @filnj @YouTube 2/24/2020\n@SpeakerPelosi asks people to "come to #Chinatown"\n\nRolls into #DC &amp; holds up… https://t.co/Dmi0FnSR8w
# 6          CatholicMom: Plagues, Wars, Facebook and Hope What new experiences is God using you to draw you closer to him this… https://t.co/M5u694wFVC
# 7         America’s healthcare workers are at war, if they were the army, they would not be told to get their own guns and bu… https://t.co/vuslwF9wqY
# 8                                                          RT @moderateRepand1: @DRoho57 @musings_mary Or wants to spread the @coronavirus to Millions
# 9                                                                               @DRoho57 @musings_mary Or wants to spread the @coronavirus to Millions
#
#               user         location
# 0     David_Ordure
# 1      TJentilucci              USA
# 2  moderateRepand1  New Jersey, USA
# 3  moderateRepand1  New Jersey, USA
# 4  moderateRepand1  New Jersey, USA
# 5  moderateRepand1  New Jersey, USA
# 6      NancyHCWard           Dallas
# 7       FlyEagles4  New Jersey, USA
# 8  moderateRepand1  New Jersey, USA
# 9  moderateRepand1  New Jersey, USA

# %%
tweet_df.user.value_counts()
# Out:
# moderateRepand1    6
# cynthiaaceleste    2
# benjamat10         2
# lauralies10p       2
# ResistUK1          2
# itsdavidaj         2
# JeanYvesMouette    2
# upendra_bage       1
# AlanUrdaibay       1
# vvibrown           1
# mo3_lyfstyle       1
# fruitiiiz          1
# QuantumDottie      1
# africanking101     1
# renatin_1          1
# AmnaadnanAD        1
# bernerlap          1
# JoAnnKennedyCAN    1
# manisha165a        1
# kryptocrib         1
# Skuby1968          1
# Zohi98104Islam     1
# ImBoredAriG        1
# jaydotseedot       1
# FlyEagles4         1
# 1martschipper1     1
# futurelawdigita    1
# davebancroft       1
# dshank92           1
# Adewumioluwad14    1
#                   ..
# SoSaveHK           1
# NancyHCWard        1
# ebner_jane         1
# fredmoser4         1
# quincy4council     1
# wifeyriddim        1
# weare3sixty        1
# BigBallerHassan    1
# HaydenAlexis3      1
# Jennife99007521    1
# kvp1982            1
# SooSUSPENDED       1
# dianasample14      1
# AndyRFCCharman     1
# Jcausey21          1
# FRInglis           1
# ansari_98          1
# DSchaubacher       1
# benwren            1
# back_fights        1
# joshglancy         1
# KRIX60             1
# Boone_Tang         1
# None_Otha30        1
# gentlyfading       1
# TJentilucci        1
# NoidaNewsIndia     1
# labrumsfuture      1
# Wessexlaw1         1
# nembotavy_0101     1
# Name: user, Length: 89, dtype: int64

# %%
tweet_df.location.value_counts()
# Out:
#                                                42
# New Jersey, USA                                 8
# Trinity Church, enterré avec mon pote Jesus     2
# Wales, United Kingdom                           2
# NYC                                             2
# pennsylvania                                    2
# Temecula, CA                                    1
# Maple, Wisconsin                                1
# North of the Isle of Wight!                     1
# New York, NY                                    1
# Dallas                                          1
# New Delhi, India                                1
# india                                           1
# London, England                                 1
# North west LONDOn                               1
# Toulouse, France                                1
# Wheathampstead, England                         1
# Pittsburgh, PA                                  1
# São Paulo, Brasil                               1
# London, UK, EUROPE                              1
# Cymru (Wales to all Heathens)                   1
# Washington, DC                                  1
# lil boston pa.                                  1
# On a blue moon                                  1
# 6.8.19 🖤 11.19.19 🖤                             1
# England, United Kingdom                         1
# Pittsburgh PA                                   1
# Great Yarmouth, England                         1
# Bhubaneswar,Odisha                              1
# up a hill                                       1
# Bruxelles                                       1
# Mars                                            1
# JNU New Delhi                                   1
# The North                                       1
# Pakistan                                        1
# Texas, USA                                      1
# Bolton, England United Kingdom                  1
# my header where it all started                  1
# iPhone: 40.425628,-79.908375                    1
# Obanikoro, Lagos                                1
# USA                                             1
# Modasa                                          1
# backup: @theroofbutera                          1
# Barpeta Road, India                             1
# York, PA                                        1
# Dublin                                          1
# Indonesia                                       1
# Pretoria and NYC                                1
# Name: location, dtype: int64

# %%
import re
def clean_tweets(text):
    text = re.sub("RT @[\w]*:","",text)
    text = re.sub("@[\w]*","",text)
    text = re.sub("https?://[A-Za-z0-9./]*","",text)
    text = re.sub("\n","",text)
    return text

# %%
tweet_df['text']=tweet_df['text'].apply(lambda x: clean_tweets(x))

# %%
tweet_df.head(20)
# Out:
#      geo  \
# 0   None
# 1   None
# 2   None
# 3   None
# 4   None
# 5   None
# 6   None
# 7   None
# 8   None
# 9   None
# 10  None
# 11  None
# 12  None
# 13  None
# 14  None
# 15  None
# 16  None
# 17  None
# 18  None
# 19  None
#
#                                                                                                                          text  \
# 0                                                                                                                        stop
# 1                                              2/24/2020 asks people to "come to #Chinatown"Rolls into #DC &amp; holds up  #…
# 2                           Please #GetWellSoon has no boundaries &amp; at this time in history #IDEOLOGY, #Race, #Political…
# 3                                     Please #GetWellSoon has no boundaries &amp; at this time in history #IDEOLOGY, #Race,…
# 4                                              2/24/2020 asks people to "come to #Chinatown"Rolls into #DC &amp; holds up  #…
# 5                                                2/24/2020 asks people to "come to #Chinatown"Rolls into #DC &amp; holds up…
# 6        CatholicMom: Plagues, Wars, Facebook and Hope What new experiences is God using you to draw you closer to him this…
# 7       America’s healthcare workers are at war, if they were the army, they would not be told to get their own guns and bu…
# 8                                                                                         Or wants to spread the  to Millions
# 9                                                                                         Or wants to spread the  to Millions
# 10                                                                              Hey  if you infect my boy , im comin' for you
# 11                                                                                     stop it. It would be very kind of you.
# 12                                                                                                                         …
# 13                Plant lovers please help !  Retweet to make awareness Plants will die - Government please do something ..…
# 14                                                       Spread the word - The  is offering to provide legal advice and whis…
# 15                                                     It's the British formula 1 team.Almost all from Britain.Mercedes is j…
# 16                                                                                                 yall messin up my diet bro
# 17                  Having rosół with udon noodles tomorrow due to limited stocks at the supermarket. Thanks a lot , you ar…
# 18                                                                                                     please say april fools
# 19   Spare a few minutes to watch the Roedean Choir perform a moving rendition of Hallelujah, conducted by the one and only …
#
#                user                       location
# 0      David_Ordure
# 1       TJentilucci                            USA
# 2   moderateRepand1                New Jersey, USA
# 3   moderateRepand1                New Jersey, USA
# 4   moderateRepand1                New Jersey, USA
# 5   moderateRepand1                New Jersey, USA
# 6       NancyHCWard                         Dallas
# 7        FlyEagles4                New Jersey, USA
# 8   moderateRepand1                New Jersey, USA
# 9   moderateRepand1                New Jersey, USA
# 10       Boone_Tang        England, United Kingdom
# 11  JimmyMcGuinnes7
# 12      AmnaadnanAD
# 13  CatherineCoombs
# 14   dafyddmihangel  Cymru (Wales to all Heathens)
# 15       benjamat10          Wales, United Kingdom
# 16  BigBallerHassan
# 17      wifeyriddim              North west LONDOn
# 18        joshuacej
# 19       joshglancy                 Washington, DC

# %%
tweet_df.to_csv('tweets.csv')

# %%
import spacy 
nlp = spacy.load('en_core_web_sm')

# %%
tweet_df['text'].apply(lambda x: [print("\tText : {}, Entity : {}".format(ent.text, ent.label_)) if (not ent.text.startswith('#')) else ""  for ent in nlp(x).ents])
# Out:
# 	Text : 2/24/2020, Entity : DATE
# 	Text : Race, Entity : PERSON
# 	Text : Race, Entity : PERSON
# 	Text : 2/24/2020, Entity : DATE
# 	Text : 2/24/2020, Entity : DATE
# 	Text : Plagues, Entity : PERSON
# 	Text : Wars, Entity : PERSON
# 	Text : America, Entity : GPE
# 	Text : Millions, Entity : CARDINAL
# 	Text : Millions, Entity : CARDINAL
# 	Text : British, Entity : NORP
# 	Text : 1, Entity : CARDINAL
# 	Text : Britain, Entity : GPE
# 	Text : Mercedes, Entity : ORG
# 	Text : tomorrow, Entity : DATE
# 	Text : april, Entity : DATE
# 	Text : a few minutes, Entity : TIME
# 	Text : Hallelujah, Entity : ORG
# 	Text : millions, Entity : CARDINAL
# 	Text : Osteen, Entity : MONEY
# 	Text : China, Entity : GPE
# 	Text : Bill Gates, Entity : PERSON
# 	Text : Millions, Entity : CARDINAL
# 	Text : Africa, Entity : LOC
# 	Text : 40, Entity : CARDINAL
# 	Text : Rona, Entity : PRODUCT
# 	Text : 🤣🤣, Entity : PERSON
# 	Text : Phoenix, Entity : GPE
# 	Text : Italy, Entity : GPE
# 	Text : 🤣🤣, Entity : PERSON
# 	Text : the last season, Entity : DATE
# 	Text : British, Entity : NORP
# 	Text : 1, Entity : CARDINAL
# 	Text : Britain, Entity : GPE
# 	Text : 422, Entity : CARDINAL
# 	Text : the last 2 days, Entity : DATE
# 	Text : HURRY UP &amp, Entity : ORG
# 	Text : 6, Entity : CARDINAL
# 	Text : Apollo13, Entity : GPE
# 	Text : NASA, Entity : ORG
# 	Text : Apollo13, Entity : GPE
# 	Text : NASA, Entity : ORG
# 	Text : Daily, Entity : DATE
# 	Text : 251, Entity : CARDINAL
# 	Text : 392, Entity : CARDINAL
# 	Text : a beautiful day, Entity : DATE
# 	Text : CNN, Entity : FAC
# 	Text : Chris Cuomo, Entity : PERSON
# 	Text : CM, Entity : ORG
# 	Text : Small Business Administration, Entity : ORG
# 	Text : 19, Entity : CARDINAL
# 	Text : consecutive hour, Entity : TIME
# 	Text : three, Entity : DATE
# 	Text : 3, Entity : CARDINAL
# 	Text : all day, Entity : DATE
# 	Text : Animal, Entity : ORG
# 	Text : first, Entity : ORDINAL
# 	Text : coronaviru, Entity : PERSON
# 	Text : Today, Entity : DATE
# 	Text : Allah Save, Entity : ORG
# 	Text : Apollo13, Entity : GPE
# 	Text : NASA, Entity : ORG
# 	Text : European Institute for Gender Equality, Entity : ORG
# 	Text : Apollo13, Entity : GPE
# 	Text : NASA, Entity : ORG
# 	Text : Apollo13, Entity : GPE
# 	Text : NASA, Entity : ORG
# 	Text : Apollo13, Entity : GPE
# 	Text : NASA, Entity : ORG
# 	Text : European Institute for Gender Equality, Entity : ORG
# 	Text : Bollywood Star, Entity : ORG
# 	Text : Home |, Entity : ORG
# 	Text : coronaviru, Entity : PERSON
# 	Text : Maulana, Entity : PERSON
# 	Text : ed, Entity : PERSON
# 	Text : lockd, Entity : PERSON
# 0                           []
# 1                     [None, ]
# 2                       [None]
# 3                       [None]
# 4                     [None, ]
# 5                     [None, ]
# 6                 [None, None]
# 7                       [None]
# 8                       [None]
# 9                       [None]
# 10                          []
# 11                          []
# 12                          []
# 13                          []
# 14                          []
# 15    [None, None, None, None]
# 16                          []
# 17                      [None]
# 18                      [None]
# 19                [None, None]
# 20                          []
# 21                          []
# 22                          []
# 23                [None, None]
# 24                      [None]
# 25                          []
# 26                          []
# 27                          []
# 28                          []
# 29          [None, None, None]
#                 ...
# 70                      [None]
# 71                          []
# 72                          []
# 73                          []
# 74                          []
# 75                          []
# 76                          []
# 77                          []
# 78                      [None]
# 79                      [None]
# 80                          []
# 81                          []
# 82                      [None]
# 83                          []
# 84                [None, None]
# 85                [None, None]
# 86                          []
# 87                          []
# 88                      [None]
# 89                [None, None]
# 90                [None, None]
# 91                          []
# 92                [None, None]
# 93                      [None]
# 94                          []
# 95                          []
# 96                          []
# 97                [None, None]
# 98                      [None]
# 99          [None, None, None]
# Name: text, Length: 100, dtype: object

# %%
tweet_df['entities']=tweet_df['text'].apply(lambda x: [(ent.text, ent.label_) if (not ent.text.startswith('#')) else "" for ent in nlp(x).ents])

# %%
tweet_df.head(20)
# Out:
#      geo  \
# 0   None
# 1   None
# 2   None
# 3   None
# 4   None
# 5   None
# 6   None
# 7   None
# 8   None
# 9   None
# 10  None
# 11  None
# 12  None
# 13  None
# 14  None
# 15  None
# 16  None
# 17  None
# 18  None
# 19  None
#
#                                                                                                                          text  \
# 0                                                                                                                        stop
# 1                                              2/24/2020 asks people to "come to #Chinatown"Rolls into #DC &amp; holds up  #…
# 2                           Please #GetWellSoon has no boundaries &amp; at this time in history #IDEOLOGY, #Race, #Political…
# 3                                     Please #GetWellSoon has no boundaries &amp; at this time in history #IDEOLOGY, #Race,…
# 4                                              2/24/2020 asks people to "come to #Chinatown"Rolls into #DC &amp; holds up  #…
# 5                                                2/24/2020 asks people to "come to #Chinatown"Rolls into #DC &amp; holds up…
# 6        CatholicMom: Plagues, Wars, Facebook and Hope What new experiences is God using you to draw you closer to him this…
# 7       America’s healthcare workers are at war, if they were the army, they would not be told to get their own guns and bu…
# 8                                                                                         Or wants to spread the  to Millions
# 9                                                                                         Or wants to spread the  to Millions
# 10                                                                              Hey  if you infect my boy , im comin' for you
# 11                                                                                     stop it. It would be very kind of you.
# 12                                                                                                                         …
# 13                Plant lovers please help !  Retweet to make awareness Plants will die - Government please do something ..…
# 14                                                       Spread the word - The  is offering to provide legal advice and whis…
# 15                                                     It's the British formula 1 team.Almost all from Britain.Mercedes is j…
# 16                                                                                                 yall messin up my diet bro
# 17                  Having rosół with udon noodles tomorrow due to limited stocks at the supermarket. Thanks a lot , you ar…
# 18                                                                                                     please say april fools
# 19   Spare a few minutes to watch the Roedean Choir perform a moving rendition of Hallelujah, conducted by the one and only …
#
#                user                       location  \
# 0      David_Ordure
# 1       TJentilucci                            USA
# 2   moderateRepand1                New Jersey, USA
# 3   moderateRepand1                New Jersey, USA
# 4   moderateRepand1                New Jersey, USA
# 5   moderateRepand1                New Jersey, USA
# 6       NancyHCWard                         Dallas
# 7        FlyEagles4                New Jersey, USA
# 8   moderateRepand1                New Jersey, USA
# 9   moderateRepand1                New Jersey, USA
# 10       Boone_Tang        England, United Kingdom
# 11  JimmyMcGuinnes7
# 12      AmnaadnanAD
# 13  CatherineCoombs
# 14   dafyddmihangel  Cymru (Wales to all Heathens)
# 15       benjamat10          Wales, United Kingdom
# 16  BigBallerHassan
# 17      wifeyriddim              North west LONDOn
# 18        joshuacej
# 19       joshglancy                 Washington, DC
#
#                                                              entities
# 0                                                                  []
# 1                                               [(2/24/2020, DATE), ]
# 2                                                    [(Race, PERSON)]
# 3                                                    [(Race, PERSON)]
# 4                                               [(2/24/2020, DATE), ]
# 5                                               [(2/24/2020, DATE), ]
# 6                                 [(Plagues, PERSON), (Wars, PERSON)]
# 7                                                    [(America, GPE)]
# 8                                              [(Millions, CARDINAL)]
# 9                                              [(Millions, CARDINAL)]
# 10                                                                 []
# 11                                                                 []
# 12                                                                 []
# 13                                                                 []
# 14                                                                 []
# 15  [(British, NORP), (1, CARDINAL), (Britain, GPE), (Mercedes, ORG)]
# 16                                                                 []
# 17                                                 [(tomorrow, DATE)]
# 18                                                    [(april, DATE)]
# 19                         [(a few minutes, TIME), (Hallelujah, ORG)]

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\udays\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sid = SentimentIntensityAnalyzer()

# %%
tweet_df['sentiment']=tweet_df['text'].apply(lambda x: sid.polarity_scores(x))

# %%
tweet_df.head(10)
# Out:
#     geo  \
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None
# 5  None
# 6  None
# 7  None
# 8  None
# 9  None
#
#                                                                                                                     text  \
# 0                                                                                                                   stop
# 1                                         2/24/2020 asks people to "come to #Chinatown"Rolls into #DC &amp; holds up  #…
# 2                      Please #GetWellSoon has no boundaries &amp; at this time in history #IDEOLOGY, #Race, #Political…
# 3                                Please #GetWellSoon has no boundaries &amp; at this time in history #IDEOLOGY, #Race,…
# 4                                         2/24/2020 asks people to "come to #Chinatown"Rolls into #DC &amp; holds up  #…
# 5                                           2/24/2020 asks people to "come to #Chinatown"Rolls into #DC &amp; holds up…
# 6   CatholicMom: Plagues, Wars, Facebook and Hope What new experiences is God using you to draw you closer to him this…
# 7  America’s healthcare workers are at war, if they were the army, they would not be told to get their own guns and bu…
# 8                                                                                    Or wants to spread the  to Millions
# 9                                                                                    Or wants to spread the  to Millions
#
#               user         location                             entities  \
# 0     David_Ordure                                                    []
# 1      TJentilucci              USA                [(2/24/2020, DATE), ]
# 2  moderateRepand1  New Jersey, USA                     [(Race, PERSON)]
# 3  moderateRepand1  New Jersey, USA                     [(Race, PERSON)]
# 4  moderateRepand1  New Jersey, USA                [(2/24/2020, DATE), ]
# 5  moderateRepand1  New Jersey, USA                [(2/24/2020, DATE), ]
# 6      NancyHCWard           Dallas  [(Plagues, PERSON), (Wars, PERSON)]
# 7       FlyEagles4  New Jersey, USA                     [(America, GPE)]
# 8  moderateRepand1  New Jersey, USA               [(Millions, CARDINAL)]
# 9  moderateRepand1  New Jersey, USA               [(Millions, CARDINAL)]
#
#                                                         sentiment
# 0        {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.296}
# 1           {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 2  {'neg': 0.133, 'neu': 0.727, 'pos': 0.139, 'compound': 0.0258}
# 3   {'neg': 0.142, 'neu': 0.71, 'pos': 0.148, 'compound': 0.0258}
# 4           {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 5           {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 6  {'neg': 0.141, 'neu': 0.664, 'pos': 0.195, 'compound': 0.1027}
# 7   {'neg': 0.151, 'neu': 0.849, 'pos': 0.0, 'compound': -0.5994}
# 8           {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 9           {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
import googlemaps

# %%
googleapikey='XXXXXXXXXXXXXXXXXXXX'
gmaps = googlemaps.Client(key=googleapikey)
geocode_result = gmaps.geocode(tweet_df['location'][1])
print(geocode_result)
print(geocode_result[0]['formatted_address'])

print(geocode_result[0]['formatted_address'].split(",")[-1].strip())
# Out:
# [{'address_components': [{'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}], 'formatted_address': 'United States', 'geometry': {'bounds': {'northeast': {'lat': 71.5388001, 'lng': -66.885417}, 'southwest': {'lat': 18.7763, 'lng': 170.5957}}, 'location': {'lat': 37.09024, 'lng': -95.712891}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 49.38, 'lng': -66.94}, 'southwest': {'lat': 25.82, 'lng': -124.39}}}, 'place_id': 'ChIJCzYy5IS16lQRQrfeQ5K5Oxw', 'types': ['country', 'political']}]
# United States
# United States

# %%
def get_country(input):
  try:
    output=gmaps.geocode(input)[0]['formatted_address'].split(",")[-1].strip()
  except:
    output="Error"
  return output

# %%
tweet_df['country']=tweet_df['location'].apply(lambda x: "" if (not x.strip()) else get_country(x))

# %%
tweet_df['country'].value_counts()
# Out:
#                   42
# USA               27
# UK                10
# India              6
# Error              5
# Indonesia          1
# South Africa       1
# France             1
# Brazil             1
# Pakistan           1
# United States      1
# Belgium            1
# Ireland            1
# Nigeria            1
# United Kingdom     1
# Name: country, dtype: int64

# %%
tweet_df.head(10)
# Out:
#     geo  \
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None
# 5  None
# 6  None
# 7  None
# 8  None
# 9  None
#
#                                                                                                                     text  \
# 0                                                                                                                   stop
# 1                                         2/24/2020 asks people to "come to #Chinatown"Rolls into #DC &amp; holds up  #…
# 2                      Please #GetWellSoon has no boundaries &amp; at this time in history #IDEOLOGY, #Race, #Political…
# 3                                Please #GetWellSoon has no boundaries &amp; at this time in history #IDEOLOGY, #Race,…
# 4                                         2/24/2020 asks people to "come to #Chinatown"Rolls into #DC &amp; holds up  #…
# 5                                           2/24/2020 asks people to "come to #Chinatown"Rolls into #DC &amp; holds up…
# 6   CatholicMom: Plagues, Wars, Facebook and Hope What new experiences is God using you to draw you closer to him this…
# 7  America’s healthcare workers are at war, if they were the army, they would not be told to get their own guns and bu…
# 8                                                                                    Or wants to spread the  to Millions
# 9                                                                                    Or wants to spread the  to Millions
#
#               user         location                             entities  \
# 0     David_Ordure                                                    []
# 1      TJentilucci              USA                [(2/24/2020, DATE), ]
# 2  moderateRepand1  New Jersey, USA                     [(Race, PERSON)]
# 3  moderateRepand1  New Jersey, USA                     [(Race, PERSON)]
# 4  moderateRepand1  New Jersey, USA                [(2/24/2020, DATE), ]
# 5  moderateRepand1  New Jersey, USA                [(2/24/2020, DATE), ]
# 6      NancyHCWard           Dallas  [(Plagues, PERSON), (Wars, PERSON)]
# 7       FlyEagles4  New Jersey, USA                     [(America, GPE)]
# 8  moderateRepand1  New Jersey, USA               [(Millions, CARDINAL)]
# 9  moderateRepand1  New Jersey, USA               [(Millions, CARDINAL)]
#
#                                                         sentiment  \
# 0        {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.296}
# 1           {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 2  {'neg': 0.133, 'neu': 0.727, 'pos': 0.139, 'compound': 0.0258}
# 3   {'neg': 0.142, 'neu': 0.71, 'pos': 0.148, 'compound': 0.0258}
# 4           {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 5           {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 6  {'neg': 0.141, 'neu': 0.664, 'pos': 0.195, 'compound': 0.1027}
# 7   {'neg': 0.151, 'neu': 0.849, 'pos': 0.0, 'compound': -0.5994}
# 8           {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 9           {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#          country
# 0
# 1  United States
# 2            USA
# 3            USA
# 4            USA
# 5            USA
# 6            USA
# 7            USA
# 8            USA
# 9            USA

# %%
tweet_df.dtypes
# Out:
# geo          object
# text         object
# user         object
# location     object
# entities     object
# sentiment    object
# country      object
# dtype: object

# %%
tweet_df.to_csv("tweets.csv")
